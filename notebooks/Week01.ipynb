# %% [markdown]
# # <font color="#C9C7BF" size="1">AI Programming Fundamentals</font>
#
# ## <font color="#C9C7BF" size="1">W01. Course Overview</font>
#
# <img src="https://raw.githubusercontent.com/youngkorea/ai-programming-fundamentals/main/img/w01_cover.svg" width="900" alt="AI Programming Fundamentals — W01. Course Overview">

# %% [markdown]
# ### <font color="#C9C7BF" size="1">1. Course Plan</font>
#
# <img src="https://raw.githubusercontent.com/youngkorea/ai-programming-fundamentals/main/img/w01_unit1.svg" width="900" alt="1. Course Plan">

# %% [markdown]
# #### <font color="#534AB7">▪ Why Learn Programming?</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Course Introduction</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Overview of Course Content</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Course Level</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ References</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Class Format</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Instructional Method</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Course Operation Strategy</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Grading</font>
#
# <img src="https://raw.githubusercontent.com/youngkorea/ai-programming-fundamentals/main/img/w01_grading_bar.svg" width="900" alt="Assignments 40, midterm 20, final 20, attendance 10, participation 10">

# %% [markdown]
# #### <font color="#534AB7">▪ Weekly Schedule</font>
#
# <img src="https://raw.githubusercontent.com/youngkorea/ai-programming-fundamentals/main/img/w01_weekly_roadmap.svg" width="900" alt="Fifteen week schedule with exams in weeks 8 and 15">

# %% [markdown]
# ### <font color="#C9C7BF" size="1">2. Introduction to Python and Colab</font>
#
# <img src="https://raw.githubusercontent.com/youngkorea/ai-programming-fundamentals/main/img/w01_unit2.svg" width="900" alt="2. Introduction to Python and Colab">

# %% [markdown]
# #### <font color="#534AB7">▪ Week Learning Objectives</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Why We Use Python for Data Analysis and AI Modeling</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Why Python is Popular</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ How to Check the Popularity of a Programming Language</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Google Colab</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Why We Use Google Colab</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Jupyter Notebook vs. Colab</font>
#
# > *(기존 본문)*

# %% [markdown]
# ### <font color="#C9C7BF" size="1">3. Getting Started with Colab</font>
#
# <img src="https://raw.githubusercontent.com/youngkorea/ai-programming-fundamentals/main/img/w01_unit3.svg" width="900" alt="3. Getting Started with Colab">

# %% [markdown]
# #### <font color="#534AB7">▪ Create a Google Account</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Open Google Colab Website</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Create or Open a Notebook</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Key Features of Google Colab</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Create a New Cell</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Write Your First Code: Hello, Colab!</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Let's Practice</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Declaring and Using Variables</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Simple Arithmetic Operations</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Automatic Output of a Code Cell</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Using Text Cells</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Writing Comments Inside Code Cells</font>
#
# > *(기존 본문)*

# %% [markdown]
# ### <font color="#C9C7BF" size="1">4. Key Takeaways</font>
#
# <img src="https://raw.githubusercontent.com/youngkorea/ai-programming-fundamentals/main/img/w01_unit4.svg" width="900" alt="4. Key Takeaways">

# %% [markdown]
# #### <font color="#534AB7">▪ Summary</font>
#
# > *(기존 본문)*

# %% [markdown]
# #### <font color="#534AB7">▪ Key Terms</font>
#
# > *(기존 본문)*
